# %% [markdown]
# # Data Analysis
#
# Now that we've got clean data, let's start with some basic financial analysis.
#
# First, let's load our CSV file into a DataFrame, convert our dates, and set the index.

# %% [markdown]
# WRDS: a great source of financial, accounting, economic, management, marketing, banking, and insurance data provided by Imperial
# (https://www.imperial.ac.uk/admin-services/library/subject-support/business/wrds/)

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/ImperialCollegeLondon/efds-ta-python/refs/heads/main/data/AAPL_2024_clean.csv")
df.Date = pd.to_datetime(df.Date)
df.set_index("Date", inplace = True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# ...                ...         ...         ...         ...         ...
# 2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 2024-05-24  188.820007  189.979996  188.039993  189.979996  189.979996
# 2024-05-28  191.509995  193.000000  189.100006  189.990005  189.990005
# 2024-05-29  189.610001  192.250000  189.509995  190.289993  190.289993
# 2024-05-30  190.759995  192.179993  190.630005  191.289993  191.289993
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500
# ...              ...
# 2024-05-23  51005900
# 2024-05-24  36294600
# 2024-05-28  52280100
# 2024-05-29  53068000
# 2024-05-30  49947900
#
# [104 rows x 6 columns]

# %% [markdown]
# ## Returns
#
# Returns refer to the gain or loss made on an initial investment, often expressed as a percentage. We can use the generic **percentage change** formula here:
#
# $$ (price_{end} - price_{start}) / price_{start} $$
#
# We can apply this to close prices to calculate the simple daily return:
#
# $$ (close price_{today} - close price_{yesterday}) / close price_{yesterday} $$
#
# When available, use the Adjusted Close price, which takes into account corporate actions (dividends for example).

# %%
# Manual Calcuation of Returns

Jan_31 = df.loc["2024-01-31", "Adj Close"]
Jan_30 = df.loc["2024-01-30", "Adj Close"]
return_Jan_31 = (Jan_31 - Jan_30)/Jan_30 
print(f'The return on January 31st 2024 was {return_Jan_31:.2%}')  # .3%: give return in 2dp and percentage
# Out:
# The return on January 31st 2024 was -1.94%

# %% [markdown]
# This simple daily return expresses a loss in value of 1.94% from one day to the next. Notice we leave our return in decimal form, but when we output it we use `f-strings` and `:.2%` to display it as a percentage.
#
# If we wanted to use the above approach to calculate daily returns for each day in our data set, it would take a long time. Let's see how we can use pandas `pct_change()` to make this sort of work easy, by applying our percentage change formula one column at a time.

# %%
# Returns 

df["Returns"] = df["Adj Close"].pct_change()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# ...                ...         ...         ...         ...         ...
# 2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 2024-05-24  188.820007  189.979996  188.039993  189.979996  189.979996
# 2024-05-28  191.509995  193.000000  189.100006  189.990005  189.990005
# 2024-05-29  189.610001  192.250000  189.509995  190.289993  190.289993
# 2024-05-30  190.759995  192.179993  190.630005  191.289993  191.289993
#
#               Volume   Returns
# Date
# 2024-01-02  82488700       NaN
# 2024-01-03  58414500 -0.007488
# 2024-01-04  71983600 -0.012700
# 2024-01-05  62303300 -0.004013
# 2024-01-08  59144500  0.024175
# ...              ...       ...
# 2024-05-23  51005900 -0.014424
# 2024-05-24  36294600  0.016588
# 2024-05-28  52280100  0.000053
# 2024-05-29  53068000  0.001579
# 2024-05-30  49947900  0.005255
#
# [104 rows x 7 columns]

# %% [markdown]
# Let's now calculate cumulative returns for the period. Instead of comparing a given day with the day before it, cumulative returns compare a given day with the first day of the period, to indicate how our stock has performed since our initial investment.
#
# We generally fill missing daily returns with a 0, which indicates no change with the day before.
#
# Because we're doing cumulative multiplication, we'll add 1 to the adjusted closing price, so we can compound the return over time. It is generally a good idea to subtract the 1 afterwards, so you clearly see the expected return.

# %%
# Cumulative Returns

df["CumReturn"] = (1 + df.Returns).cumprod() - 1
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# ...                ...         ...         ...         ...         ...
# 2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 2024-05-24  188.820007  189.979996  188.039993  189.979996  189.979996
# 2024-05-28  191.509995  193.000000  189.100006  189.990005  189.990005
# 2024-05-29  189.610001  192.250000  189.509995  190.289993  190.289993
# 2024-05-30  190.759995  192.179993  190.630005  191.289993  191.289993
#
#               Volume   Returns  CumReturn
# Date
# 2024-01-02  82488700       NaN        NaN
# 2024-01-03  58414500 -0.007488  -0.007488
# 2024-01-04  71983600 -0.012700  -0.020093
# 2024-01-05  62303300 -0.004013  -0.024025
# 2024-01-08  59144500  0.024175  -0.000431
# ...              ...       ...        ...
# 2024-05-23  51005900 -0.014424   0.007964
# 2024-05-24  36294600  0.016588   0.024684
# 2024-05-28  52280100  0.000053   0.024738
# 2024-05-29  53068000  0.001579   0.026356
# 2024-05-30  49947900  0.005255   0.031750
#
# [104 rows x 8 columns]

# %% [markdown]
# ### Exercise: Buy & Hold
#
# #### Part 1
#
# Imagine you had bought AAPL at the start of 2024. What would your expected return have been had you sold at the end of April, compared with holding until the end of May and selling then?

# %%
print(f'The return of selling at the end of April 2024 was {df.CumReturn.loc["2024-04-30"]:.2%}')
print(f'The return of selling at the end of May 2024 was {df.CumReturn.loc["2024-05-30"]:.2%}')
# Out:
# The return of selling at the end of April 2024 was -8.13%
# The return of selling at the end of May 2024 was 3.18%

# %% [markdown]
# #### Part 2
#
# What if you had bought at the start of May, and sold at the end of the month?

# %%
may_cum_return = (1 + df.Returns.loc["2024-05"]).prod() - 1   # prod(): same as cumprod() but only giving you the last value 
print(f'The cumulative return over May 2024 was {may_cum_return:.2%}')
# Out:
# The cumulative return over May 2024 was 12.31%

# %% [markdown]
# ## Moving Averages
#
# Moving averages are a different kind of indicator, one that smooths out small variations in trading data to give a better picture of the overall trend.
#
# A Simple Moving Average (SMA) is one which averages out a price over a specific period. The average is "moving" because when a new day is considered in the period, the oldest date is discarded.
#
# Moving averages can be *fast*, when they cover a short period, or *slow* when they consider a longer period. The longer the period, the more those small variations are smoothed out.

# %%
df["FastSMA"] = df["Adj Close"].rolling(window = 20).mean()   # usually 2-50 days for fast SMA

df["SlowSMA"] = df["Adj Close"].rolling(window = 100).mean()   # not so useful for small dataset - a lot of missing value 

df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# ...                ...         ...         ...         ...         ...
# 2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 2024-05-24  188.820007  189.979996  188.039993  189.979996  189.979996
# 2024-05-28  191.509995  193.000000  189.100006  189.990005  189.990005
# 2024-05-29  189.610001  192.250000  189.509995  190.289993  190.289993
# 2024-05-30  190.759995  192.179993  190.630005  191.289993  191.289993
#
#               Volume   Returns  CumReturn     FastSMA     SlowSMA
# Date
# 2024-01-02  82488700       NaN        NaN         NaN         NaN
# 2024-01-03  58414500 -0.007488  -0.007488         NaN         NaN
# 2024-01-04  71983600 -0.012700  -0.020093         NaN         NaN
# 2024-01-05  62303300 -0.004013  -0.024025         NaN         NaN
# 2024-01-08  59144500  0.024175  -0.000431         NaN         NaN
# ...              ...       ...        ...         ...         ...
# 2024-05-23  51005900 -0.014424   0.007964  182.982251  179.617692
# 2024-05-24  36294600  0.016588   0.024684  184.016251  179.663458
# 2024-05-28  52280100  0.000053   0.024738  184.840751  179.723206
# 2024-05-29  53068000  0.001579   0.026356  185.838751  179.809324
# 2024-05-30  49947900  0.005255   0.031750  186.938250  179.912733
#
# [104 rows x 10 columns]

# %% [markdown]
# ## Surges
#
# Surges in price or trading volume can be helpful indicators for traders. We can define a surge as an increase on the day before by an amount higher than some set threshold. A common threshold is two standard deviations above the mean. Since price surges consider the change in price between two trading days, we use our already calculated daily returns, which provide that value for us!

# %%
mean_return = df.Returns.mean()

threshold = mean_return + (df.Returns.std()*2)

condition = df.Returns > threshold

df[condition]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-18  186.089996  189.139999  185.830002  187.119995  188.389618
# 2024-04-11  168.339996  175.460007  170.196207  175.039993  175.039993
# 2024-05-02  172.509995  173.419998  170.889999  173.029999  176.340004
# 2024-05-03  186.649994  187.000000  182.660004  183.380005  183.380005
#
#                Volume   Returns  CumReturn     FastSMA  SlowSMA
# Date
# 2024-01-18   78005800  0.032571   0.016107         NaN      NaN
# 2024-04-11   91070300  0.043271  -0.055897  171.547499      NaN
# 2024-05-02   94214900  0.041583  -0.048885  169.980000      NaN
# 2024-05-03  163224100  0.039923  -0.010914  170.670000      NaN

# %% [markdown]
# ### Exercise: In the news
#
# Can you find any events associated with the days you identified as price surges?
# - Jan: Bank of America upgrade Apple stock from neutral to buy
# - May: A recorded stock buyback
